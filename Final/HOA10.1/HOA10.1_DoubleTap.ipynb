# %% [markdown]
# [Github](https://github.com/KenPascual/CPE311_Computational-Thinking-with-Python/tree/6c22dc832ffdb0d184c5476d46d9ee724069cbde/Final/HOA10.1)

# %% [markdown]
# # Hands-on Activity 10.1: Data Analysis using Python

# %% [markdown]
# 1. Gather a dataset regarding your identified problem for the ASEAN Data Science Explorer. Make sure that the dataset includes multiple variables.
# 2. Load the dataset into pandas dataframe.
# 3. Prepare the data by applying appropriate data preprocessing techniques.
# 4. Analyze the data using descriptive analysis.
# 4. Perform correlation analysis.
# 5. Interpret the results based on the descriptive and correlation analysis.
# 6. Submit the PDF file.

# %% [markdown]
# ## Extract

# %%
import pandas as pd
acc = pd.read_csv('datasets/traffic_accidents.csv')

# %%
inj = pd.read_csv('datasets/injured_casualties.csv')

# %%
dead = pd.read_csv('datasets/dead_casualties.csv')

# %%
xprs = pd.read_csv('datasets/expressway_length.csv')
xprs.head(12)
# Out:
#     Unnamed: 0   year Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0      country   2008       2009       2010       2011       2012       2013
# 1     Cambodia    NaN        NaN        NaN        NaN        NaN        NaN
# 2    Indonesia    722        722        758        758        758        774
# 3      Lao PDR    NaN        NaN        NaN        NaN        NaN        NaN
# 4     Malaysia  1 544      1 635      1 666      1 742      1 817      1 837
# 5      Myanmar    NaN        324        587        666        587        587
# 6  Philippines    297        286        312        312        312        312
# 7    Singapore    161        161        161        161        161        164
# 8     Thailand    176        208        208        208        208        208
# 9     Viet Nam     19         19         89         89        167        167
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...

# %% [markdown]
# ## Transform

# %%
# clean the data by fixing the problem of the column names being in the first row
# Fixing column names and resetting index properly

acc.columns = acc.iloc[0]         
acc = acc[1:]                     
accidents = acc.reset_index(drop=True) 

inj.columns = inj.iloc[0]
inj = inj[1:]
injured = inj.reset_index(drop=True)

dead.columns = dead.iloc[0]
dead = dead[1:]
deceased = dead.reset_index(drop=True)

xprs.columns = xprs.iloc[0]
xprs = xprs[1:]
express = xprs.reset_index(drop=True)

# %%
express.head(12)
# Out:
# 0      country   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 0     Cambodia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    Indonesia    722    722    758    758    758    774    820    948  1 035
# 2      Lao PDR    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3     Malaysia  1 544  1 635  1 666  1 742  1 817  1 837  1 997  2 021  1 988
# 4      Myanmar    NaN    324    587    666    587    587    590    590    590
# 5  Philippines    297    286    312    312    312    312    357    378    386
# 6    Singapore    161    161    161    161    161    164    164    164    164
# 7     Thailand    176    208    208    208    208    208    208    208    225
# 8     Viet Nam     19     19     89     89    167    167    476    699    745
#
# 0   2017   2018   2019   2020   2021   2022   2023  2024.0
# 0    NaN    NaN    NaN    187    187    187    187     NaN
# 1    820  1 082  2 093  2 334  2 457  2 583    NaN     NaN
# ...

# %%
# Suppose your column is named 'Country'
individual_dfs = {}

for country in accidents['country'].unique():
    individual_dfs[country] = accidents[accidents['country'] == country]

# %%
Myanmar_df = individual_dfs['Myanmar']
# Out:
# 0  country   2004   2005   2006   2007   2008   2009   2010    2011    2012  \
# 5  Myanmar  5 905  5 755  6 778  6 939  7 204  8 461  9 020  10 123  11 675
#
# 0  ...    2015    2016    2017    2018    2019    2020   2021   2022   2023  \
# 5  ...  15 859  17 384  18 171  17 452  16 167  12 973  6 420  5 631  4 772
#
# 0   2024
# 5  2 446
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Load
