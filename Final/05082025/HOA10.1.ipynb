# %% [markdown]
# # Hands-on Activity 10.1: Data Analysis using Python

# %% [markdown]
# 1. Gather a dataset regarding your identified problem for the ASEAN Data Science Explorer. Make sure that the dataset includes multiple variables.
# 2. Load the dataset into pandas dataframe.
# 3. Prepare the data by applying appropriate data preprocessing techniques.
# 4. Analyze the data using descriptive analysis.
# 4. Perform correlation analysis.
# 5. Interpret the results based on the descriptive and correlation analysis.
# 6. Submit the PDF file.

# %%
import pandas as pd
accidents = pd.read_csv('datasets/traffic_accidents.csv')
accidents.head()
# Out:
#           Unnamed: 0    year Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0            country    2004       2005       2006       2007       2008
# 1  Brunei Darussalam   2 624      2 771      2 710      2 674      2 775
# 2           Cambodia   4 255      6 301      9 338      8 994     10 015
# 3          Indonesia  17 732     91 623     87 020     49 553     59 164
# 4            Lao PDR   1 136      3 212      3 770      4 824      5 024
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13  \
# 0       2009       2010       2011       2012  ...        2015        2016
# 1      3 110      3 414      3 598      3 310  ...       3 346       3 375
# 2     12 538      6 941      5 096      4 250  ...       4 519       3 910
# 3     62 960     66 488    109 776    117 949  ...      98 970     106 644
# 4      5 233      5 638      5 935      6 146  ...       5 571       5 616
#
# ...

# %%
injured = pd.read_csv('datasets/injured_casualties.csv')
incident.head()
# Out:
#           Unnamed: 0    year Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0            country    2004       2005       2006       2007       2008
# 1  Brunei Darussalam   2 624      2 771      2 710      2 674      2 775
# 2           Cambodia   4 255      6 301      9 338      8 994     10 015
# 3          Indonesia  17 732     91 623     87 020     49 553     59 164
# 4            Lao PDR   1 136      3 212      3 770      4 824      5 024
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13  \
# 0       2009       2010       2011       2012  ...        2015        2016
# 1      3 110      3 414      3 598      3 310  ...       3 346       3 375
# 2     12 538      6 941      5 096      4 250  ...       4 519       3 910
# 3     62 960     66 488    109 776    117 949  ...      98 970     106 644
# 4      5 233      5 638      5 935      6 146  ...       5 571       5 616
#
# ...

# %%
dead = pd.read_csv('datasets/dead_casualties.csv')
incident.head()
# Out:
#           Unnamed: 0    year Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0            country    2004       2005       2006       2007       2008
# 1  Brunei Darussalam   2 624      2 771      2 710      2 674      2 775
# 2           Cambodia   4 255      6 301      9 338      8 994     10 015
# 3          Indonesia  17 732     91 623     87 020     49 553     59 164
# 4            Lao PDR   1 136      3 212      3 770      4 824      5 024
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13  \
# 0       2009       2010       2011       2012  ...        2015        2016
# 1      3 110      3 414      3 598      3 310  ...       3 346       3 375
# 2     12 538      6 941      5 096      4 250  ...       4 519       3 910
# 3     62 960     66 488    109 776    117 949  ...      98 970     106 644
# 4      5 233      5 638      5 935      6 146  ...       5 571       5 616
#
# ...

# %%
expressway = pd.read_csv('datasets/expressway_length.csv')
incident.head()
# Out:
#           Unnamed: 0    year Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0            country    2004       2005       2006       2007       2008
# 1  Brunei Darussalam   2 624      2 771      2 710      2 674      2 775
# 2           Cambodia   4 255      6 301      9 338      8 994     10 015
# 3          Indonesia  17 732     91 623     87 020     49 553     59 164
# 4            Lao PDR   1 136      3 212      3 770      4 824      5 024
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13  \
# 0       2009       2010       2011       2012  ...        2015        2016
# 1      3 110      3 414      3 598      3 310  ...       3 346       3 375
# 2     12 538      6 941      5 096      4 250  ...       4 519       3 910
# 3     62 960     66 488    109 776    117 949  ...      98 970     106 644
# 4      5 233      5 638      5 935      6 146  ...       5 571       5 616
#
# ...

# %%
accidents.columns = accidents.iloc[0]
accidents = accidents[1:]
accidents.reset_index(drop=True, inplace=True)

injured.columns = injured.iloc[0]
injured = accidents[1:]
injured.reset_index(drop=True, inplace=True)

dead.columns = dead.iloc[0]
dead = accidents[1:]
dead.reset_index(drop=True, inplace=True)

expressway.columns = expressway.iloc[0]
expressway = accidents[1:]
expressway.reset_index(drop=True, inplace=True)

# %%
injured.head()
# Out:
# 0    country     2004     2005     2006     2007     2008     2009     2010  \
# 0   Cambodia    4 255    6 301    9 338    8 994   10 015   12 538    6 941
# 1  Indonesia   17 732   91 623   87 020   49 553   59 164   62 960   66 488
# 2    Lao PDR    1 136    3 212    3 770    4 824    5 024    5 233    5 638
# 3   Malaysia  326 817  328 327  341 252  363 319  373 071  397 330  414 421
# 4    Myanmar    5 905    5 755    6 778    6 939    7 204    8 461    9 020
#
# 0     2011     2012  ...     2015     2016     2017     2018     2019  \
# 0    5 096    4 250  ...    4 519    3 910    3 686    3 352    4 141
# 1  109 776  117 949  ...   98 970  106 644  104 327  109 215  116 411
# 2    5 935    6 146  ...    5 571    5 616    5 868    5 909    6 616
# 3  449 040  462 423  ...  489 606  521 466  533 875  548 598  567 516
# 4   10 123   11 675  ...   15 859   17 384   18 171   17 452   16 167
#
# 0     2020     2021     2022     2023   2024
# ...
