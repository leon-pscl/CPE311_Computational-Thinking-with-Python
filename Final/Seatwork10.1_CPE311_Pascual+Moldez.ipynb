# %% [markdown]
# # Seatwork 10.1 Case Study: Improving RT-IoT2022 Analysis

# %% [markdown]
# ### What could be done better?

# %% [markdown]
# ## Extract

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
IoT = pd.read_csv('datasets/RT_IOT2022.csv')
IoT.count()
# Out:
# no                      123117
# id.orig_p               123117
# id.resp_p               123117
# proto                   123117
# service                 123117
#                          ...
# idle.std                123117
# fwd_init_window_size    123117
# bwd_init_window_size    123117
# fwd_last_window_size    123117
# Attack_type             123117
# Length: 85, dtype: int64

# %%
IoT.columns
# Out:
# Index(['no', 'id.orig_p', 'id.resp_p', 'proto', 'service', 'flow_duration',
#        'fwd_pkts_tot', 'bwd_pkts_tot', 'fwd_data_pkts_tot',
#        'bwd_data_pkts_tot', 'fwd_pkts_per_sec', 'bwd_pkts_per_sec',
#        'flow_pkts_per_sec', 'down_up_ratio', 'fwd_header_size_tot',
#        'fwd_header_size_min', 'fwd_header_size_max', 'bwd_header_size_tot',
#        'bwd_header_size_min', 'bwd_header_size_max', 'flow_FIN_flag_count',
#        'flow_SYN_flag_count', 'flow_RST_flag_count', 'fwd_PSH_flag_count',
#        'bwd_PSH_flag_count', 'flow_ACK_flag_count', 'fwd_URG_flag_count',
#        'bwd_URG_flag_count', 'flow_CWR_flag_count', 'flow_ECE_flag_count',
#        'fwd_pkts_payload.min', 'fwd_pkts_payload.max', 'fwd_pkts_payload.tot',
#        'fwd_pkts_payload.avg', 'fwd_pkts_payload.std', 'bwd_pkts_payload.min',
#        'bwd_pkts_payload.max', 'bwd_pkts_payload.tot', 'bwd_pkts_payload.avg',
#        'bwd_pkts_payload.std', 'flow_pkts_payload.min',
# ...

# %%
IoT.head(10)
# Out:
#    no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0   0      38667       1883   tcp    mqtt      32.011598             9
# 1   1      51143       1883   tcp    mqtt      31.883584             9
# 2   2      44761       1883   tcp    mqtt      32.124053             9
# 3   3      60893       1883   tcp    mqtt      31.961063             9
# 4   4      51087       1883   tcp    mqtt      31.902362             9
# 5   5      48579       1883   tcp    mqtt      31.869686             9
# 6   6      54063       1883   tcp    mqtt      32.094711             9
# 7   7      33457       1883   tcp    mqtt      32.104011             9
# 8   8      52181       1883   tcp    mqtt      32.026967             9
# 9   9      53469       1883   tcp    mqtt      32.048637             9
#
#    bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  active.std  \
# 0             5                  3                  3  ...         0.0
# ...

# %%
IoT.tail(10)
# Out:
#           no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 123107  2000      59247      55600   tcp       -       0.000007             1
# 123108  2001      59247      57797   tcp       -       0.000006             1
# 123109  2002      59247      60020   tcp       -       0.000007             1
# 123110  2003      59247      60443   tcp       -       0.000006             1
# 123111  2004      59247      61900   tcp       -       0.000007             1
# 123112  2005      59247      63331   tcp       -       0.000006             1
# 123113  2006      59247      64623   tcp       -       0.000007             1
# 123114  2007      59247      64680   tcp       -       0.000006             1
# 123115  2008      59247      65000   tcp       -       0.000006             1
# 123116  2009      59247      65129   tcp       -       0.000006             1
#
#         bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  active.std  \
# ...

# %%
IoT.dtypes
# Out:
# no                        int64
# id.orig_p                 int64
# id.resp_p                 int64
# proto                    object
# service                  object
#                          ...
# idle.std                float64
# fwd_init_window_size      int64
# bwd_init_window_size      int64
# fwd_last_window_size      int64
# Attack_type              object
# Length: 85, dtype: object

# %%
print(IoT['Attack_type'].values)
# Out:
# ['MQTT_Publish' 'MQTT_Publish' 'MQTT_Publish' ... 'NMAP_XMAS_TREE_SCAN'
#  'NMAP_XMAS_TREE_SCAN' 'NMAP_XMAS_TREE_SCAN']

# %% [markdown]
# ## Transform

# %%
#Sorting by flow_duration
IoT = IoT.sort_values(by='flow_duration',ascending=False)
IoT.head(20)
# Out:
#           no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 12506    252      59766       6667   udp       -   21728.335578          4345
# 12505    251      40434       8886   tcp     ssl   18761.401291           704
# 12420    166      62366       6667   udp       -   17747.121108          3549
# 12419    165      40261       8886   tcp     ssl   17732.696970           671
# 12317     63      62969       6667   udp       -    9433.886888          1887
# 12285     31      62969       6667   udp       -    9433.886888          1887
# 12316     62      40545       8886   tcp       -    9379.541767           440
# 12284     30      40545       8886   tcp       -    9379.541767           440
# 12353     99      40533       8886   tcp       -    6950.994837           398
# 12342     88      62969       6667   udp       -    6828.456767          1344
# 12438    184      40856       8886   tcp     ssl    5678.531132           274
# ...

# %%
IoT.tail(20)
# Out:
#            no  id.orig_p  id.resp_p proto service  flow_duration  \
# 63962   43171      46086         21   tcp       -            0.0
# 109857  89066      62322         21   tcp       -            0.0
# 63863   43072      45987         21   tcp       -            0.0
# 63861   43070      45985         21   tcp       -            0.0
# 63858   43067      45982         21   tcp       -            0.0
# 27020    6229       9071         21   tcp       -            0.0
# 63846   43055      45970         21   tcp       -            0.0
# 109938  89147      63683         21   tcp       -            0.0
# 27007    6216       9058         21   tcp       -            0.0
# 109947  89156      64632         21   tcp       -            0.0
# 63827   43036      45951         21   tcp       -            0.0
# 63826   43035      45950         21   tcp       -            0.0
# 26998    6207       9049         21   tcp       -            0.0
# ...

# %% [markdown]
# ## Load

# %%
IoT.describe()
# Out:
#                   no      id.orig_p      id.resp_p  flow_duration  \
# count  123117.000000  123117.000000  123117.000000  123117.000000
# mean    37035.089248   34639.258738    1014.305092       3.809566
# std     30459.106367   19070.620354    5256.371994     130.005408
# min         0.000000       0.000000       0.000000       0.000000
# 25%      6059.000000   17702.000000      21.000000       0.000001
# 50%     33100.000000   37221.000000      21.000000       0.000004
# 75%     63879.000000   50971.000000      21.000000       0.000005
# max     94658.000000   65535.000000   65389.000000   21728.335578
#
#         fwd_pkts_tot   bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  \
# count  123117.000000  123117.000000      123117.000000      123117.000000
# mean        2.268826       1.909509           1.471218           0.820260
# std        22.336565      33.018311          19.635196          32.293948
# min         0.000000       0.000000           0.000000           0.000000
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
IoT = pd.read_csv('datasets/RT_IOT2022.csv')

# %%
IoT.dtypes
# Out:
# no                        int64
# id.orig_p                 int64
# id.resp_p                 int64
# proto                    object
# service                  object
#                          ...
# idle.std                float64
# fwd_init_window_size      int64
# bwd_init_window_size      int64
# fwd_last_window_size      int64
# Attack_type              object
# Length: 85, dtype: object

# %%
#get the rarest attacks, analyze them
IoT['Attack_type'].unique()
# Out:
# <StringArray>
# [              'MQTT_Publish',                'Thing_Speak',
#                  'Wipro_bulb',             'ARP_poisioning',
#              'DDOS_Slowloris',              'DOS_SYN_Hping',
#  'Metasploit_Brute_Force_SSH',              'NMAP_FIN_SCAN',
#           'NMAP_OS_DETECTION',              'NMAP_TCP_scan',
#               'NMAP_UDP_SCAN',        'NMAP_XMAS_TREE_SCAN']
# Length: 12, dtype: string

# %%
IoT_filter = IoT[['no','id.orig_p','id.orig_p','proto','service','flow_duration','fwd_pkts_tot','bwd_pkts_tot','fwd_data_pkts_tot','bwd_data_pkts_tot','Attack_type']]

# %%
IoT_filter.head()
# Out:
#    no  id.orig_p  id.orig_p proto service  flow_duration  fwd_pkts_tot  \
# 0   0      38667      38667   tcp    mqtt      32.011598             9
# 1   1      51143      51143   tcp    mqtt      31.883584             9
# 2   2      44761      44761   tcp    mqtt      32.124053             9
# 3   3      60893      60893   tcp    mqtt      31.961063             9
# 4   4      51087      51087   tcp    mqtt      31.902362             9
#
#    bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot   Attack_type
# 0             5                  3                  3  MQTT_Publish
# 1             5                  3                  3  MQTT_Publish
# 2             5                  3                  3  MQTT_Publish
# 3             5                  3                  3  MQTT_Publish
# 4             5                  3                  3  MQTT_Publish

# %%
ATK9 = IoT_filter.loc[IoT_filter['Attack_type'] == 'MQTT_Publish']

# %%
ATK9['no'].count()
# Out:
# 4146

# %%
ATK10 = IoT_filter.loc[IoT_filter['Attack_type'] == 'Thing_Speak']

# %%
ATK10['no'].count()
# Out:
# 8108

# %%
ATK11 = IoT_filter.loc[IoT_filter['Attack_type'] == 'Wipro_bulb']

# %%
ATK11['no'].count()
# Out:
# 253

# %%
ATK1 = IoT_filter.loc[IoT_filter['Attack_type'] == 'ARP_poisioning']

# %%
ATK1['no'].count()
# Out:
# 7750

# %%
#summary statistics for rows with values DDOS_Slowloris in Attack_type column
ATK12 = IoT_filter.loc[IoT_filter['Attack_type'] == 'DDOS_Slowloris']

# %%
ATK12['no'].count()
# Out:
# 534

# %%
#summary statistics for rows with values DOS_SYN_Hping in Attack_type column
ATK2 = IoT_filter.loc[IoT_filter['Attack_type'] == 'DOS_SYN_Hping']

# %%
ATK2['no'].count()
# Out:
# 94659

# %%
#summary statistics for rows with values Metasploit_Brute_Force_SSH in Attack_type column
ATK8 = IoT_filter.loc[IoT_filter['Attack_type'] == 'Metasploit_Brute_Force_SSH']

# %%
ATK8['no'].count()
# Out:
# 37

# %%
#summary statistics for rows with values NMAP_FIN_SCAN in Attack_type column
ATK7 = IoT_filter.loc[IoT_filter['Attack_type'] == 'NMAP_FIN_SCAN']

# %%
ATK7['no'].count()
# Out:
# 28

# %%
#summary statistics for rows with values NMAP_OS_DETECTION in Attack_type column
ATK3 = IoT_filter.loc[IoT_filter['Attack_type'] == 'NMAP_OS_DETECTION ']

# %%
ATK3['no'].count()
# Out:
# 0

# %%
#summary statistics for rows with values NMAP_TCP_scan in Attack_type column
ATK4 = IoT_filter.loc[IoT_filter['Attack_type'] == 'NMAP_TCP_scan']

# %%
ATK4['no'].count()
# Out:
# 1002

# %%
#summary statistics for rows with values NMAP_UDP_SCAN in Attack_type column
ATK5 = IoT_filter.loc[IoT_filter['Attack_type'] == 'NMAP_UDP_SCAN']

# %%
ATK5['no'].count()
# Out:
# 2590

# %%
#summary statistics for rows with values NMAP_XMAS_TREE_SCAN in Attack_type column
ATK6 = IoT_filter.loc[IoT_filter['Attack_type'] == 'NMAP_XMAS_TREE_SCAN']

# %%
ATK6['no'].count()
# Out:
# 2010

# %% [markdown]
# Guide Questions
