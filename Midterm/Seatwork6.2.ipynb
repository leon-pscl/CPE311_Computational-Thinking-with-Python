# %%
import pandas as pd
meteorites = pd.read_csv('datasets/Meteorite_Landings.csv', nrows=5)
meteorites['name']
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
meteorites.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
import requests

response = requests.get(
    'https://data.nas.gov/resource/gh4g-9sfh.json',
    params = {'$limit':50_000}
)

if response.ok:
    payload = response.json()
else:
    print(f'Request not successful and returned code: {response.status_code}.')
    payload = None
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
import requests

response = requests.get(
    'https://data.nasa.gov/resource/gh4g-9sfh.json',
    params = {'$limit':10}
)

if response.ok:
    payload = response.json()
else:
    print(f'Request not successful and returned code: {response.status_code}.')
    payload = None

payload
# Out:
# [{'name': 'Aachen',
#   'id': '1',
#   'nametype': 'Valid',
#   'recclass': 'L5',
#   'mass': '21',
#   'fall': 'Fell',
#   'year': '1880-01-01T00:00:00.000',
#   'reclat': '50.775000',
#   'reclong': '6.083330',
#   'geolocation': {'latitude': '50.775', 'longitude': '6.08333'}},
#  {'name': 'Aarhus',
#   'id': '2',
#   'nametype': 'Valid',
#   'recclass': 'H6',
#   'mass': '720',
#   'fall': 'Fell',
#   'year': '1951-01-01T00:00:00.000',
#   'reclat': '56.183330',
#   'reclong': '10.233330',
#   'geolocation': {'latitude': '56.18333', 'longitude': '10.23333'}},
#  {'name': 'Abee',
#   'id': '6',
#   'nametype': 'Valid',
#   'recclass': 'EH4',
#   'mass': '107000',
#   'fall': 'Fell',
#   'year': '1952-01-01T00:00:00.000',
#   'reclat': '54.216670',
#   'reclong': '-113.000000',
#   'geolocation': {'latitude': '54.21667', 'longitude': '-113.0'}},
#  {'name': 'Acapulco',
#   'id': '10',
#   'nametype': 'Valid',
#   'recclass': 'Acapulcoite',
#   'mass': '1914',
#   'fall': 'Fell',
# ...

# %%
df = pd.DataFrame(payload)
df.head(10)
# Out:
#                   name   id nametype     recclass    mass  fall  \
# 0               Aachen    1    Valid           L5      21  Fell
# 1               Aarhus    2    Valid           H6     720  Fell
# 2                 Abee    6    Valid          EH4  107000  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914  Fell
# 4              Achiras  370    Valid           L6     780  Fell
# 5             Adhi Kot  379    Valid          EH4    4239  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910  Fell
# 7                 Agen  392    Valid           H5   30000  Fell
# 8               Aguada  398    Valid           L6    1620  Fell
# 9        Aguila Blanca  417    Valid            L    1440  Fell
#
#                       year      reclat      reclong  \
# 0  1880-01-01T00:00:00.000   50.775000     6.083330
# 1  1951-01-01T00:00:00.000   56.183330    10.233330
# 2  1952-01-01T00:00:00.000   54.216670  -113.000000
# ...

# %%
import pandas as pd
meteorites = pd.read_csv('datasets/Meteorite_Landings.csv', nrows=100)

# %%
meteorites.shape
# Out:
# (100, 10)

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
meteorites.head(10)
#display first 10
# Out:
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
meteorites.tail(10)
#display last 10
# Out:
#             name     id nametype recclass  mass (g)  fall  \
# 90  Beaver Creek   4986    Valid       H5   14000.0  Fell
# 91    Beddgelert   4993    Valid       H5     794.0  Fell
# 92         Bells   5005    Valid   C2-ung     375.0  Fell
# 93      Belville   5009    Valid       OC       NaN  Fell
# 94   Benares (a)   5011    Valid      LL4    3700.0  Fell
# 95     Benguerir  30443    Valid      LL6   25000.0  Fell
# 96   Beni M'hira   5018    Valid       L6   19000.0  Fell
# 97         Benld   5021    Valid       H6    1770.5  Fell
# 98        Benoni   5023    Valid       H6    3880.0  Fell
# 99       Bensour   5024    Valid      LL6   45000.0  Fell
#
#                       year    reclat    reclong             GeoLocation
# 90  01/01/1893 12:00:00 AM  51.16667 -117.33333  (51.16667, -117.33333)
# 91  01/01/1949 12:00:00 AM  53.01667   -4.10000        (53.01667, -4.1)
# 92  01/01/1961 12:00:00 AM  33.60000  -96.46667       (33.6, -96.46667)
# ...

# %%
meteorites.info()
#important to take note if may kulang or what
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         100 non-null    object
#  1   id           100 non-null    int64
#  2   nametype     100 non-null    object
#  3   recclass     100 non-null    object
#  4   mass (g)     96 non-null     float64
#  5   fall         100 non-null    object
#  6   year         99 non-null     object
#  7   reclat       100 non-null    float64
#  8   reclong      100 non-null    float64
#  9   GeoLocation  100 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 7.9+ KB

# %%
meteorites['id','mass','Geolocation']
#will not work
#enclose it to a list to work
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('id', 'mass', 'Geolocation')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 meteorites['id','mass','Geolocation']
#
# ...

# %%
meteorites[['id','fall','GeoLocation']]
#enclose it to a list to work
# Out:
#        id  fall            GeoLocation
# 0       1  Fell      (50.775, 6.08333)
# 1       2  Fell   (56.18333, 10.23333)
# 2       6  Fell     (54.21667, -113.0)
# 3      10  Fell      (16.88333, -99.9)
# 4     370  Fell    (-33.16667, -64.95)
# ..    ...   ...                    ...
# 95  30443  Fell         (32.25, -8.15)
# 96   5018  Fell       (32.86667, 10.8)
# 97   5021  Fell     (39.08333, -89.15)
# 98   5023  Fell  (-26.16667, 28.41667)
# 99   5024  Fell           (30.0, -7.0)
#
# [100 rows x 3 columns]

# %%
import pandas as pd
meteorites = pd.read_csv('datasets/Meteorite_Landings.csv', nrows=1200)
meteorites[100:104]
#given [x:y], y is exclusive, so in this case, it will just display until 103

# %%
import pandas as pd
meteorites = pd.read_csv('datasets/Meteorite_Landings.csv', nrows=100)
meteorites.iloc[100:104, [0,3,4,6]]
# Out:
#               name       recclass  mass (g)                    year
# 100         Benton            LL6    2840.0  01/01/1949 12:00:00 AM
# 101         Berduc             L6     270.0  01/01/2008 12:00:00 AM
# 102         Béréba  Eucrite-mmict   18000.0  01/01/1924 12:00:00 AM
# 103  Berlanguillas             L6    1440.0  01/01/1811 12:00:00 AM

# %%
meteorites.loc[100:104, 'mass (g)']
#selecting column name
# Out:
# 100     2840.0
# 101      270.0
# 102    18000.0
# 103     1440.0
# 104      960.0
# Name: mass (g), dtype: float64

# %%
meteorites.iloc[:,-1]
#view last column of all rows
# Out:
# 0          (50.775, 6.08333)
# 1       (56.18333, 10.23333)
# 2         (54.21667, -113.0)
# 3          (16.88333, -99.9)
# 4        (-33.16667, -64.95)
#                ...
# 195     (23.69639, -5.01472)
# 196             (53.7, 30.1)
# 197    (35.03333, -81.88333)
# 198         (46.55, 6.81667)
# 199         (50.83333, 34.0)
# Name: GeoLocation, Length: 200, dtype: object

# %%
meteorites.iloc[-1,:]
#view last row with all columns
# Out:
# name                     Chervony Kut
# id                               5342
# nametype                        Valid
# recclass                Eucrite-mmict
# mass (g)                       1700.0
# fall                             Fell
# year           01/01/1939 12:00:00 AM
# reclat                       50.83333
# reclong                          34.0
# GeoLocation          (50.83333, 34.0)
# Name: 199, dtype: object

# %%
import pandas as pd
meteorites = pd.read_csv('datasets/Meteorite_Landings.csv')
#boolean masking to filter the dataset
meteorites[(meteorites['mass (g)'] > 1e6) & (meteorites.fall == 'Fell')]
# Out:
#               name     id nametype    recclass    mass (g)  fall  \
# 29         Allende   2278    Valid         CV3   2000000.0  Fell
# 419          Jilin  12171    Valid          H5   4000000.0  Fell
# 506  Kunya-Urgench  12379    Valid          H5   1100000.0  Fell
# 707  Norton County  17922    Valid     Aubrite   1100000.0  Fell
# 920   Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 29   01/01/1969 12:00:00 AM  26.96667 -105.31667  (26.96667, -105.31667)
# 419  01/01/1976 12:00:00 AM  44.05000  126.16667      (44.05, 126.16667)
# 506  01/01/1998 12:00:00 AM  42.25000   59.20000           (42.25, 59.2)
# 707  01/01/1948 12:00:00 AM  39.68333  -99.86667   (39.68333, -99.86667)
# 920  01/01/1947 12:00:00 AM  46.16000  134.65333      (46.16, 134.65333)

# %%
meteorites.query("`mass (g)` > 1e6 and fall == 'Fell'")
#alternative
# Out:
#               name     id nametype    recclass    mass (g)  fall  \
# 29         Allende   2278    Valid         CV3   2000000.0  Fell
# 419          Jilin  12171    Valid          H5   4000000.0  Fell
# 506  Kunya-Urgench  12379    Valid          H5   1100000.0  Fell
# 707  Norton County  17922    Valid     Aubrite   1100000.0  Fell
# 920   Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 29   01/01/1969 12:00:00 AM  26.96667 -105.31667  (26.96667, -105.31667)
# 419  01/01/1976 12:00:00 AM  44.05000  126.16667      (44.05, 126.16667)
# 506  01/01/1998 12:00:00 AM  42.25000   59.20000           (42.25, 59.2)
# 707  01/01/1948 12:00:00 AM  39.68333  -99.86667   (39.68333, -99.86667)
# 920  01/01/1947 12:00:00 AM  46.16000  134.65333      (46.16, 134.65333)

# %%
meteorites.describe()
#summary stats
# Out:
#                  id      mass (g)       reclat      reclong
# count   1200.000000  1.168000e+03  1187.000000  1187.000000
# mean   15342.849167  4.340465e+04    29.871203    18.716994
# std    11051.483532  6.880153e+05    22.277417    66.623760
# min        1.000000  1.000000e-01   -44.116670  -157.866670
# 25%     6640.000000  5.112500e+02    23.839860    -1.508335
# 50%    14667.000000  2.210000e+03    34.900000    14.052170
# 75%    22780.500000  9.000000e+03    45.295835    74.383330
# max    57168.000000  2.300000e+07    66.348330   174.400000

# %%
meteorites.fall.value_counts()
#counts entries with such values
#It will count ilan yung may "Fell" and ilan yung may "Found"
# Out:
# fall
# Fell     1107
# Found      93
# Name: count, dtype: int64

# %%
meteorites.value_counts(subset=['nametype','fall'],normalize=False)
# Out:
# nametype  fall
# Valid     Found    44534
#           Fell      1107
# Relict    Found       75
# Name: count, dtype: int64

# %%
meteorites.value_counts(subset=['nametype','fall'],normalize=True)
# Out:
# nametype  fall
# Valid     Found    0.974145
#           Fell     0.024215
# Relict    Found    0.001641
# Name: proportion, dtype: float64

# %%
float(meteorites['mass (g)'].mean().round(2))
# Out:
# 13278.08

# %%
meteorites['mass (g)'].quantile(0.1)
# Out:
# 2.1

# %%
meteorites['mass (g)'].median()
#50th percentile
# Out:
# 32.6

# %%
meteorites['mass (g)'].max()
# Out:
# 60000000.0

# %%
meteorites.loc[meteorites['mass (g)'].idxmin()]
# Out:
# name                             Gove
# id                              52859
# nametype                       Relict
# recclass                  Relict iron
# mass (g)                          0.0
# fall                            Found
# year           01/01/1979 12:00:00 AM
# reclat                      -12.26333
# reclong                     136.83833
# GeoLocation    (-12.26333, 136.83833)
# Name: 12640, dtype: object

# %%
meteorites.loc[meteorites['mass (g)'].idxmax()]
# Out:
# name                             Hoba
# id                              11890
# nametype                        Valid
# recclass                    Iron, IVB
# mass (g)                   60000000.0
# fall                            Found
# year           01/01/1920 12:00:00 AM
# reclat                      -19.58333
# reclong                      17.91667
# GeoLocation     (-19.58333, 17.91667)
# Name: 16392, dtype: object

# %%
meteorites.recclass.nunique()
#how many different types of meteorite classes are represented in this dataset?
# Out:
# 466

# %%
meteorites.recclass.unique()[:14]
# Out:
# array(['L5', 'H6', 'EH4', 'Acapulcoite', 'L6', 'LL3-6', 'H5', 'L',
#        'Diogenite-pm', 'Unknown', 'H4', 'H', 'Iron, IVA', 'CR2-an'],
#       dtype=object)

# %% [markdown]
# meteorites.name.nunique()

# %%
meteorites.describe(include='all')
# Out:
#           name            id nametype recclass      mass (g)   fall  \
# count    45716  45716.000000    45716    45716  4.558500e+04  45716
# unique   45716           NaN        2      466           NaN      2
# top     Aachen           NaN    Valid       L6           NaN  Found
# freq         1           NaN    45641     8285           NaN  44609
# mean       NaN  26889.735104      NaN      NaN  1.327808e+04    NaN
# std        NaN  16860.683030      NaN      NaN  5.749889e+05    NaN
# min        NaN      1.000000      NaN      NaN  0.000000e+00    NaN
# 25%        NaN  12688.750000      NaN      NaN  7.200000e+00    NaN
# 50%        NaN  24261.500000      NaN      NaN  3.260000e+01    NaN
# 75%        NaN  40656.750000      NaN      NaN  2.026000e+02    NaN
# max        NaN  57458.000000      NaN      NaN  6.000000e+07    NaN
#
#                           year        reclat       reclong GeoLocation
# count                    45425  38401.000000  38401.000000       38401
# ...

# %% [markdown]
# # Exercise (Part 1)

# %% [markdown]
# ## Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.

# %%
import pandas as pd
taxi = pd.read_csv('datasets/2019_Yellow_Taxi_Trip_Data.csv')
taxi.head(5)
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# ...

# %% [markdown]
# ## Find the dimensions (number of rows and number of columns) in the data.

# %%
taxi.shape
# Out:
# (10000, 18)

# %% [markdown]
# ## Using the data in the 2019_Yellow_Taxi_Trip_Data.csv file, calculate summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns.

# %%
filter_taxi = taxi[['fare_amount','tip_amount','tolls_amount','total_amount','trip_distance']]
#to get summary statistics
filter_taxi.describe()
# Out:
#         fare_amount    tip_amount  tolls_amount  total_amount  trip_distance
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean      15.106313      2.634494      0.623447     22.564659       3.015250
# std       13.954762      3.409800      6.437507     19.209255       4.148063
# min      -52.000000      0.000000     -6.120000    -65.920000       0.000000
# 25%        7.000000      0.000000      0.000000     12.375000       0.920000
# 50%       10.000000      2.000000      0.000000     16.300000       1.500000
# 75%       16.000000      3.250000      0.000000     22.880000       2.760000
# max      176.000000     43.000000    612.000000    671.800000      38.110000

# %% [markdown]
# ## Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

# %%
filter_taxi.loc[filter_taxi['fare_amount'].idxmax()]
#should be taxis.loc[taxis.trip_distance.idxmax(),["columns needed"]
# Out:
# fare_amount      176.00
# tip_amount        18.29
# tolls_amount       6.12
# total_amount     201.21
# trip_distance     38.11
# Name: 8338, dtype: float64

# %% [markdown]
# ### Reflection

# %% [markdown]
# In this exercise, as well as in the discussion, I was able to be familiarized with the different use cases of the pandas library for data analysis. I was able to learn about the basics such as opening and creating dataframes, selecting columns and indexes, filtering via boolean masking, and identifying data types and dataframe dimensions.
#
# Furthermore, I was able to learn about new syntax such as idxmax and idxmin to locate specific elements within the dataframe. Lastly, I was able to learn about different ways to get relevant statistics to a given dataset.
#
# In the exercise, I failed to totally not rely on the notes I had during the discussion when doing the activity. I believe this merely requires a bit more practice, so I have to work on it. Overall, this activity was fun and engaging, and I had a lot of takeaways from it.
